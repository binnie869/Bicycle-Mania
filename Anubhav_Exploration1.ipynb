# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
from datetime import timedelta

# %%
df = pd.read_csv("DATA/babs_open_data_year_1/201402_babs_open_data/201402_trip_data.csv")

# %%
df[4000:4020]
# Out:
#       Trip ID  Duration      Start Date  \
# 4000    10165       772  9/3/2013 19:14
# 4001    10166       754  9/3/2013 19:14
# 4002    10168       471  9/3/2013 19:15
# 4003    10169       794  9/3/2013 19:20
# 4004    10171       783  9/3/2013 19:20
# 4005    10172       363  9/3/2013 19:21
# 4006    10173       601  9/3/2013 19:23
# 4007    10174      1044  9/3/2013 19:24
# 4008    10175       770  9/3/2013 19:26
# 4009    10176       242  9/3/2013 19:28
# 4010    10177       571  9/3/2013 19:29
# 4011    10178       523  9/3/2013 19:30
# 4012    10179       926  9/3/2013 19:31
# 4013    10183       832  9/3/2013 19:33
# 4014    10184       801  9/3/2013 19:34
# 4015    10185      1061  9/3/2013 19:36
# 4016    10186       671  9/3/2013 19:38
# 4017    10187       576  9/3/2013 19:40
# 4018    10188       643  9/3/2013 19:40
# 4019    10189       532  9/3/2013 19:45
#
#                                  Start Station  Start Terminal  \
# 4000                           Post at Kearney              47
# 4001                           Post at Kearney              47
# 4002                             2nd at Folsom              62
# 4003                        Powell Street BART              39
# 4004                        Powell Street BART              39
# 4005  San Francisco Caltrain (Townsend at 4th)              70
# 4006                           Clay at Battery              41
# 4007                   San Francisco City Hall              58
# 4008                  Commercial at Montgomery              45
# 4009                             2nd at Folsom              62
# 4010                  Commercial at Montgomery              45
# 4011                  Commercial at Montgomery              45
# 4012           Grant Avenue at Columbus Avenue              73
# 4013                    Embarcadero at Vallejo              48
# 4014                    Embarcadero at Vallejo              48
# 4015                      Paseo de San Antonio               7
# 4016                           2nd at Townsend              61
# 4017                           2nd at Townsend              61
# 4018                        Powell Street BART              39
# 4019                     Washington at Kearney              46
#
#             End Date                               End Station  End Terminal  \
# 4000  9/3/2013 19:27                     Embarcadero at Folsom            51
# 4001  9/3/2013 19:27                     Embarcadero at Folsom            51
# 4002  9/3/2013 19:23  San Francisco Caltrain (Townsend at 4th)            70
# 4003  9/3/2013 19:33                           Clay at Battery            41
# 4004  9/3/2013 19:33                           Clay at Battery            41
# 4005  9/3/2013 19:27                           Townsend at 7th            65
# 4006  9/3/2013 19:33             Powell at Post (Union Square)            71
# 4007  9/3/2013 19:41                           Spear at Folsom            49
# 4008  9/3/2013 19:39           Grant Avenue at Columbus Avenue            73
# 4009  9/3/2013 19:32                             5th at Howard            57
# 4010  9/3/2013 19:38           Grant Avenue at Columbus Avenue            73
# 4011  9/3/2013 19:38           Grant Avenue at Columbus Avenue            73
# 4012  9/3/2013 19:46         Civic Center BART (7th at Market)            72
# 4013  9/3/2013 19:47      Harry Bridges Plaza (Ferry Building)            50
# 4014  9/3/2013 19:47      Harry Bridges Plaza (Ferry Building)            50
# 4015  9/3/2013 19:54                    SJSU 4th at San Carlos            12
# 4016  9/3/2013 19:49                         Steuart at Market            74
# 4017  9/3/2013 19:49                          Davis at Jackson            42
# 4018  9/3/2013 19:51                     Embarcadero at Folsom            51
# 4019  9/3/2013 19:54                             Market at 4th            76
#
#       Bike # Subscription Type Zip Code
# 4000     543        Subscriber    94105
# 4001     415        Subscriber    94105
# 4002     485        Subscriber    94107
# 4003     528          Customer      NaN
# 4004     494          Customer      NaN
# 4005     557        Subscriber    94103
# 4006     508        Subscriber    94107
# 4007     634        Subscriber    94105
# 4008     537          Customer      NaN
# 4009     462          Customer      NaN
# 4010     553          Customer      NaN
# 4011     273          Customer      NaN
# 4012     603        Subscriber    94117
# 4013     567          Customer    94019
# 4014     517          Customer    94402
# 4015      24          Customer    95113
# 4016     548          Customer    94401
# 4017     540        Subscriber    94111
# 4018     613        Subscriber    94107
# 4019     589        Subscriber    94597

# %%
df.rename(columns = {'Start Date':'Start Date Time', 'End Date':'End Date Time'}, inplace = True)

# %%
df['Start Date'], df['Start Time'] = zip(*df['Start Date Time'].apply(lambda x: x.split(' ')))
df['End Date'], df['End Time'] = zip(*df['End Date Time'].apply(lambda x: x.split(' ')))

# %%
df.head()
# Out:
#    Trip ID  Duration  Start Date Time             Start Station  \
# 0     4576        63  8/29/2013 14:13  South Van Ness at Market
# 1     4607        70  8/29/2013 14:42        San Jose City Hall
# 2     4130        71  8/29/2013 10:16   Mountain View City Hall
# 3     4251        77  8/29/2013 11:29        San Jose City Hall
# 4     4299        83  8/29/2013 12:02  South Van Ness at Market
#
#    Start Terminal    End Date Time               End Station  End Terminal  \
# 0              66  8/29/2013 14:14  South Van Ness at Market            66
# 1              10  8/29/2013 14:43        San Jose City Hall            10
# 2              27  8/29/2013 10:17   Mountain View City Hall            27
# 3              10  8/29/2013 11:30        San Jose City Hall            10
# 4              66  8/29/2013 12:04            Market at 10th            67
#
#    Bike # Subscription Type Zip Code Start Date Start Time   End Date End Time
# 0     520        Subscriber    94127  8/29/2013      14:13  8/29/2013    14:14
# 1     661        Subscriber    95138  8/29/2013      14:42  8/29/2013    14:43
# 2      48        Subscriber    97214  8/29/2013      10:16  8/29/2013    10:17
# 3      26        Subscriber    95060  8/29/2013      11:29  8/29/2013    11:30
# 4     319        Subscriber    94103  8/29/2013      12:02  8/29/2013    12:04

# %%
df.shape
# Out:
# (144015, 15)

# %%
df_loc = pd.read_csv("DATA/babs_open_data_year_1/201402_babs_open_data/201402_station_data.csv")

# %%
df_loc.head()
# Out:
#    station_id                               name        lat        long  \
# 0           2  San Jose Diridon Caltrain Station  37.329732 -121.901782
# 1           3              San Jose Civic Center  37.330698 -121.888979
# 2           4             Santa Clara at Almaden  37.333988 -121.894902
# 3           5                   Adobe on Almaden  37.331415 -121.893200
# 4           6                   San Pedro Square  37.336721 -121.894074
#
#    dockcount  landmark installation
# 0         27  San Jose     8/6/2013
# 1         15  San Jose     8/5/2013
# 2         11  San Jose     8/6/2013
# 3         19  San Jose     8/5/2013
# 4         15  San Jose     8/7/2013

# %%
df_merged_1 = pd.merge(df, df_loc, left_on='Start Station', right_on='name', how='inner', sort=False)

# %%
df_merged_1.shape
# Out:
# (144015, 22)

# %%
df_merged_1.head()
# Out:
#    Trip ID  Duration  Start Date Time             Start Station  \
# 0     4576        63  8/29/2013 14:13  South Van Ness at Market
# 1     4299        83  8/29/2013 12:02  South Van Ness at Market
# 2     4760       113  8/29/2013 17:01  South Van Ness at Market
# 3     5070       168  8/29/2013 21:43  South Van Ness at Market
# 4     4765       228  8/29/2013 17:05  South Van Ness at Market
#
#    Start Terminal    End Date Time               End Station  End Terminal  \
# 0              66  8/29/2013 14:14  South Van Ness at Market            66
# 1              66  8/29/2013 12:04            Market at 10th            67
# 2              66  8/29/2013 17:03  South Van Ness at Market            66
# 3              66  8/29/2013 21:46  South Van Ness at Market            66
# 4              66  8/29/2013 17:08            Market at 10th            67
#
#    Bike # Subscription Type      ...      Start Time   End Date End Time  \
# 0     520        Subscriber      ...           14:13  8/29/2013    14:14
# 1     319        Subscriber      ...           12:02  8/29/2013    12:04
# 2     553        Subscriber      ...           17:01  8/29/2013    17:03
# 3     598        Subscriber      ...           21:43  8/29/2013    21:46
# 4     553        Subscriber      ...           17:05  8/29/2013    17:08
#
#   station_id                      name        lat        long  dockcount  \
# 0         66  South Van Ness at Market  37.774814 -122.418954         19
# 1         66  South Van Ness at Market  37.774814 -122.418954         19
# 2         66  South Van Ness at Market  37.774814 -122.418954         19
# 3         66  South Van Ness at Market  37.774814 -122.418954         19
# 4         66  South Van Ness at Market  37.774814 -122.418954         19
#
#         landmark  installation
# 0  San Francisco     8/23/2013
# 1  San Francisco     8/23/2013
# 2  San Francisco     8/23/2013
# 3  San Francisco     8/23/2013
# 4  San Francisco     8/23/2013
#
# [5 rows x 22 columns]

# %%
df_merged_1.rename(columns = {'lat':'Start Latitute', 'long':'Start Longitude', 'dockcount': 'Start Station Dockcount', 'landmark': 'Start Station Landmark', 'installation': 'Start Station Installation'}, inplace = True)

# %%
df_merged_1.head()
# Out:
#    Trip ID  Duration  Start Date Time             Start Station  \
# 0     4576        63  8/29/2013 14:13  South Van Ness at Market
# 1     4299        83  8/29/2013 12:02  South Van Ness at Market
# 2     4760       113  8/29/2013 17:01  South Van Ness at Market
# 3     5070       168  8/29/2013 21:43  South Van Ness at Market
# 4     4765       228  8/29/2013 17:05  South Van Ness at Market
#
#    Start Terminal    End Date Time               End Station  End Terminal  \
# 0              66  8/29/2013 14:14  South Van Ness at Market            66
# 1              66  8/29/2013 12:04            Market at 10th            67
# 2              66  8/29/2013 17:03  South Van Ness at Market            66
# 3              66  8/29/2013 21:46  South Van Ness at Market            66
# 4              66  8/29/2013 17:08            Market at 10th            67
#
#    Bike # Subscription Type             ...             Start Time   End Date  \
# 0     520        Subscriber             ...                  14:13  8/29/2013
# 1     319        Subscriber             ...                  12:02  8/29/2013
# 2     553        Subscriber             ...                  17:01  8/29/2013
# 3     598        Subscriber             ...                  21:43  8/29/2013
# 4     553        Subscriber             ...                  17:05  8/29/2013
#
#   End Time station_id                      name  Start Latitute  \
# 0    14:14         66  South Van Ness at Market       37.774814
# 1    12:04         66  South Van Ness at Market       37.774814
# 2    17:03         66  South Van Ness at Market       37.774814
# 3    21:46         66  South Van Ness at Market       37.774814
# 4    17:08         66  South Van Ness at Market       37.774814
#
#   Start Longitude  Start Station Dockcount  Start Station Landmark  \
# 0     -122.418954                       19           San Francisco
# 1     -122.418954                       19           San Francisco
# 2     -122.418954                       19           San Francisco
# 3     -122.418954                       19           San Francisco
# 4     -122.418954                       19           San Francisco
#
#    Start Station Installation
# 0                   8/23/2013
# 1                   8/23/2013
# 2                   8/23/2013
# 3                   8/23/2013
# 4                   8/23/2013
#
# [5 rows x 22 columns]

# %%
df_merged_1 = df_merged_1.drop('name', 1)

# %%
df_merged_1 = pd.merge(df_merged_1, df_loc, left_on='End Station', right_on='name', how='inner', sort=False)

# %%
df_merged_1.head()
# Out:
#    Trip ID  Duration  Start Date Time             Start Station  \
# 0     4576        63  8/29/2013 14:13  South Van Ness at Market
# 1     4760       113  8/29/2013 17:01  South Van Ness at Market
# 2     5070       168  8/29/2013 21:43  South Van Ness at Market
# 3     4584       262  8/29/2013 14:17  South Van Ness at Market
# 4     4079       995   8/29/2013 9:35  South Van Ness at Market
#
#    Start Terminal    End Date Time               End Station  End Terminal  \
# 0              66  8/29/2013 14:14  South Van Ness at Market            66
# 1              66  8/29/2013 17:03  South Van Ness at Market            66
# 2              66  8/29/2013 21:46  South Van Ness at Market            66
# 3              66  8/29/2013 14:21  South Van Ness at Market            66
# 4              66   8/29/2013 9:52  South Van Ness at Market            66
#
#    Bike # Subscription Type     ...      Start Station Dockcount  \
# 0     520        Subscriber     ...                           19
# 1     553        Subscriber     ...                           19
# 2     598        Subscriber     ...                           19
# 3     587        Subscriber     ...                           19
# 4     327        Subscriber     ...                           19
#
#   Start Station Landmark Start Station Installation station_id_y  \
# 0          San Francisco                  8/23/2013           66
# 1          San Francisco                  8/23/2013           66
# 2          San Francisco                  8/23/2013           66
# 3          San Francisco                  8/23/2013           66
# 4          San Francisco                  8/23/2013           66
#
#                        name        lat        long  dockcount       landmark  \
# 0  South Van Ness at Market  37.774814 -122.418954         19  San Francisco
# 1  South Van Ness at Market  37.774814 -122.418954         19  San Francisco
# 2  South Van Ness at Market  37.774814 -122.418954         19  San Francisco
# 3  South Van Ness at Market  37.774814 -122.418954         19  San Francisco
# 4  South Van Ness at Market  37.774814 -122.418954         19  San Francisco
#
#   installation
# 0    8/23/2013
# 1    8/23/2013
# 2    8/23/2013
# 3    8/23/2013
# 4    8/23/2013
#
# [5 rows x 28 columns]

# %%
df_merged_1.rename(columns = {'lat':'End Latitute', 'long':'End Longitude', 'dockcount': 'End Station Dockcount', 'landmark': 'End Station Landmark', 'installation': 'End Station Installation'}, inplace = True)

# %%
df_merged_1 = df_merged_1.drop('name', 1)

# %%
df_merged_1.to_csv("DATA/babs_open_data_year_1/201402_babs_open_data/201402_merged_data.csv", index=False)

# %%
df_merged_1.head()
# Out:
#    Trip ID  Duration Start Date             Start Station  Start Terminal  \
# 0     4576        63  8/29/2013  South Van Ness at Market              66
# 1     4760       113  8/29/2013  South Van Ness at Market              66
# 2     5070       168  8/29/2013  South Van Ness at Market              66
# 3     4584       262  8/29/2013  South Van Ness at Market              66
# 4     4079       995  8/29/2013  South Van Ness at Market              66
#
#     End Date               End Station  End Terminal  Bike #  \
# 0  8/29/2013  South Van Ness at Market            66     520
# 1  8/29/2013  South Van Ness at Market            66     553
# 2  8/29/2013  South Van Ness at Market            66     598
# 3  8/29/2013  South Van Ness at Market            66     587
# 4  8/29/2013  South Van Ness at Market            66     327
#
#   Subscription Type            ...            Start Longitude  \
# 0        Subscriber            ...                -122.418954
# 1        Subscriber            ...                -122.418954
# 2        Subscriber            ...                -122.418954
# 3        Subscriber            ...                -122.418954
# 4        Subscriber            ...                -122.418954
#
#   Start Station Dockcount Start Station Landmark  Start Station Installation  \
# 0                      19          San Francisco                   8/23/2013
# 1                      19          San Francisco                   8/23/2013
# 2                      19          San Francisco                   8/23/2013
# 3                      19          San Francisco                   8/23/2013
# 4                      19          San Francisco                   8/23/2013
#
#    station_id_y  End Latitute  End Longitude End Station Dockcount  \
# 0            66     37.774814    -122.418954                    19
# 1            66     37.774814    -122.418954                    19
# 2            66     37.774814    -122.418954                    19
# 3            66     37.774814    -122.418954                    19
# 4            66     37.774814    -122.418954                    19
#
#   End Station Landmark  End Station Installation
# 0        San Francisco                 8/23/2013
# 1        San Francisco                 8/23/2013
# 2        San Francisco                 8/23/2013
# 3        San Francisco                 8/23/2013
# 4        San Francisco                 8/23/2013
#
# [5 rows x 25 columns]
